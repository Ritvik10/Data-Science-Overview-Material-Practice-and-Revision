# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritvik10/Data-Science-Overview-Material-Practice-and-Revision/blob/main/Day_33_Project_4_Data_Analysis_on_Olympics_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset
#
# Athlete: https://drive.google.com/file/d/1Bu98ZzOctRPlUVkzjSHK6dH29cvgY46d/view?usp=sharing
#
#
# NOC: https://drive.google.com/file/d/1uFftpcc1CBEmA8SWjilK2Q5Ofb5Ck-h0/view?usp=sharing

# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# # Reading the dattset

# %%
athlete = pd.read_csv('/content/drive/MyDrive/Datasets/athlete_events.csv')
noc = pd.read_csv('/content/drive/MyDrive/Datasets/noc_regions.csv')

# %% [markdown]
# # Creating a copy of the DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ath = athlete.copy()
cou = noc.copy()

# %% [markdown]
# # Data Exploration

# %%
ath.head()
# Out:
#    ID                      Name Gender   Age  Height  Weight            Team  \
# 0   1                 A Dijiang      M  24.0   180.0    80.0           China
# 1   2                  A Lamusi      M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby      M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye      M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink      F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
ath.tail()
# Out:
#             ID                Name Gender   Age  Height  Weight      Team  \
# 271111  135569          Andrzej ya      M  29.0   179.0    89.0  Poland-1
# 271112  135570            Piotr ya      M  27.0   176.0    59.0    Poland
# 271113  135570            Piotr ya      M  27.0   176.0    59.0    Poland
# 271114  135571  Tomasz Ireneusz ya      M  30.0   185.0    96.0    Poland
# 271115  135571  Tomasz Ireneusz ya      M  34.0   185.0    96.0    Poland
#
#         NOC        Games  Year  Season            City        Sport  \
# 271111  POL  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  POL  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  POL  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  POL  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  POL  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping Men's Large Hill, Individual   NaN
# 271113        Ski Jumping Men's Large Hill, Team   NaN
# 271114                      Bobsleigh Men's Four   NaN
# 271115                      Bobsleigh Men's Four   NaN

# %%
ath.shape
# Out:
# (271116, 15)

# %%
cou.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
cou.shape
# Out:
# (230, 3)

# %%
ath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Gender  271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
cou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
ath.isna().sum()
# Out:
# ID             0
# Name           0
# Gender         0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
# Find out the ratio of null & not null values in the medal column
x=ath["Medal"].isna().sum()
y=ath["Medal"].notnull().sum()
print(x,":",y)
# Out:
# 231333 : 39783

# %% [markdown]
# # Data Cleaning & Data Manipulation

# %% [markdown]
# * Find all the rows (Datapoints) in the NOC dataframe where region is NaN

# %%
cou
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
cou[cou['region'].isna()]
# Out:
#      NOC region                 notes
# 168  ROT    NaN  Refugee Olympic Team
# 208  TUV    NaN                Tuvalu
# 213  UNK    NaN               Unknown

# %%
# Show all the rows from the athlete DataFrame where the region is ROT, TUV & UNK
ath.loc[ath['NOC'].isin(['ROT','TUV','UNK'])]
# Out:
#             ID                     Name Gender   Age  Height  Weight  \
# 6267      3515      Paulo Amotun Lokoro      M  24.0   170.0    61.0
# 7908      4379                Rami Anis      M  25.0   178.0    78.0
# 7909      4379                Rami Anis      M  25.0   178.0    78.0
# 21529    11364           Yiech Pur Biel      M  21.0   178.0    62.0
# 31708    16287    Mabika Yolande Bukasa      F  28.0   170.0    70.0
# 40238    20693   James Nyang Chiengjiek      M  24.0   179.0    59.0
# 61080    31292             Fritz Eccard      M   NaN     NaN     NaN
# 64674    33094              Logona Esau      M  21.0   163.0    69.0
# 119392   60444              Yonas Kinde      M  36.0   172.0    57.0
# 130721   65813                A. Laffen      M   NaN     NaN     NaN
# 132436   66655         Tuau Lapua Lapua      M  21.0   140.0    62.0
# 141669   71067  Anjelina Nadai Lohalith      F  23.0   163.0    50.0
# 141753   71113    Rose Nathike Lokonyen      F  21.0   157.0    50.0
# 148612   74540            Asenate Manoa      F  16.0     NaN    46.0
# 148613   74540            Asenate Manoa      F  20.0     NaN    46.0
# 149306   74902            Yusra Mardini      F  18.0   157.0    53.0
# 149307   74902            Yusra Mardini      F  18.0   157.0    53.0
# 160069   80325           Popole Misenga      M  24.0   180.0    90.0
# 172492   86663             Tavevele Noa      M  20.0   176.0    74.0
# 240317  120422          Etimoni Timuani      M  24.0   184.0    72.0
# 240342  120439          Okilani Tinilau      M  19.0     NaN     NaN
#
#                             Team  NOC        Games  Year  Season  \
# 6267    Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 7908    Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 7909    Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 21529   Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 31708   Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 40238   Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 61080                    Unknown  UNK  1912 Summer  1912  Summer
# 64674                     Tuvalu  TUV  2008 Summer  2008  Summer
# 119392  Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 130721                   Unknown  UNK  1912 Summer  1912  Summer
# 132436                    Tuvalu  TUV  2012 Summer  2012  Summer
# 141669  Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 141753  Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 148612                    Tuvalu  TUV  2008 Summer  2008  Summer
# 148613                    Tuvalu  TUV  2012 Summer  2012  Summer
# 149306  Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 149307  Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 160069  Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
# 172492                    Tuvalu  TUV  2012 Summer  2012  Summer
# 240317                    Tuvalu  TUV  2016 Summer  2016  Summer
# 240342                    Tuvalu  TUV  2008 Summer  2008  Summer
#
#                   City             Sport  \
# 6267    Rio de Janeiro         Athletics
# 7908    Rio de Janeiro          Swimming
# 7909    Rio de Janeiro          Swimming
# 21529   Rio de Janeiro         Athletics
# 31708   Rio de Janeiro              Judo
# 40238   Rio de Janeiro         Athletics
# 61080        Stockholm  Art Competitions
# 64674          Beijing     Weightlifting
# 119392  Rio de Janeiro         Athletics
# 130721       Stockholm  Art Competitions
# 132436          London     Weightlifting
# 141669  Rio de Janeiro         Athletics
# 141753  Rio de Janeiro         Athletics
# 148612         Beijing         Athletics
# 148613          London         Athletics
# 149306  Rio de Janeiro          Swimming
# 149307  Rio de Janeiro          Swimming
# 160069  Rio de Janeiro              Judo
# 172492          London         Athletics
# 240317  Rio de Janeiro         Athletics
# 240342         Beijing         Athletics
#
#                                         Event Medal
# 6267             Athletics Men's 1,500 metres   NaN
# 7908      Swimming Men's 100 metres Freestyle   NaN
# 7909      Swimming Men's 100 metres Butterfly   NaN
# 21529              Athletics Men's 800 metres   NaN
# 31708               Judo Women's Middleweight   NaN
# 40238              Athletics Men's 400 metres   NaN
# 61080     Art Competitions Mixed Architecture   NaN
# 64674         Weightlifting Men's Lightweight   NaN
# 119392               Athletics Men's Marathon   NaN
# 130721    Art Competitions Mixed Architecture   NaN
# 132436      Weightlifting Men's Featherweight   NaN
# 141669         Athletics Women's 1,500 metres   NaN
# 141753           Athletics Women's 800 metres   NaN
# 148612           Athletics Women's 100 metres   NaN
# 148613           Athletics Women's 100 metres   NaN
# 149306  Swimming Women's 100 metres Freestyle   NaN
# 149307  Swimming Women's 100 metres Butterfly   NaN
# 160069                Judo Men's Middleweight   NaN
# 172492             Athletics Men's 100 metres   NaN
# 240317             Athletics Men's 100 metres   NaN
# 240342             Athletics Men's 100 metres   NaN

# %% [markdown]
# * Add a column "Region" to the ath DataFrame. And the region column should have the region according to the elements in the NOC column of the countries DataFrame.

# %%
ath.columns
# Out:
# Index(['ID', 'Name', 'Gender', 'Age', 'Height', 'Weight', 'Team', 'NOC',
#        'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
cou.columns
# Out:
# Index(['NOC', 'region', 'notes'], dtype='object')

# %%
region = ath['NOC'].map(cou.set_index('NOC')['region'])

# %%
region
# Out:
# 0               China
# 1               China
# 2             Denmark
# 3             Denmark
# 4         Netherlands
#              ...
# 271111         Poland
# 271112         Poland
# 271113         Poland
# 271114         Poland
# 271115         Poland
# Name: NOC, Length: 271116, dtype: object

# %%
ath.insert(7, 'Region', region)

# %%
ath.columns
# Out:
# Index(['ID', 'Name', 'Gender', 'Age', 'Height', 'Weight', 'Team', 'Region',
#        'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
# Delete the NOC column from the ath DataFrame
ath.drop('NOC', axis=1, inplace=True)

# %%
ath.head(1)
# Out:
#    ID       Name Gender   Age  Height  Weight   Team Region        Games  \
# 0   1  A Dijiang      M  24.0   180.0    80.0  China  China  1992 Summer
#
#    Year  Season       City       Sport                        Event Medal
# 0  1992  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %% [markdown]
# Handling the null values in the columns - Age, Height, Weight (From ath DataFrame)

# %%
# Find the minimun age
ath.Age.min()
# Out:
# 10.0

# %%
ath.Age.max()
# Out:
# 97.0

# %%
ath.Age.describe()
# Out:
# count    261642.000000
# mean         25.556898
# std           6.393561
# min          10.000000
# 25%          21.000000
# 50%          24.000000
# 75%          28.000000
# max          97.000000
# Name: Age, dtype: float64

# %%
# Fill all the NaN values with the mean value of the Age column
ath["Age"].fillna(ath.Age.mean(), inplace = True)

# %%
ath.Age
# Out:
# 0         24.0
# 1         23.0
# 2         24.0
# 3         34.0
# 4         21.0
#           ...
# 271111    29.0
# 271112    27.0
# 271113    27.0
# 271114    30.0
# 271115    34.0
# Name: Age, Length: 271116, dtype: float64

# %%
ath.Age = ath.Age.astype('int')

# %%
ath.Age
# Out:
# 0         24
# 1         23
# 2         24
# 3         34
# 4         21
#           ..
# 271111    29
# 271112    27
# 271113    27
# 271114    30
# 271115    34
# Name: Age, Length: 271116, dtype: int64

# %%
ath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Gender  271116 non-null  object
#  3   Age     271116 non-null  int64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   Region  270746 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 31.0+ MB

# %%
ath.Height.describe()
# Out:
# count    210945.000000
# mean        175.338970
# std          10.518462
# min         127.000000
# 25%         168.000000
# 50%         175.000000
# 75%         183.000000
# max         226.000000
# Name: Height, dtype: float64

# %%
ath.Weight.describe()
# Out:
# count    208241.000000
# mean         70.702393
# std          14.348020
# min          25.000000
# 25%          60.000000
# 50%          70.000000
# 75%          79.000000
# max         214.000000
# Name: Weight, dtype: float64

# %%
ath["Height"].fillna(ath.Height.mean(), inplace = True)
ath["Weight"].fillna(ath.Weight.mean(), inplace = True)

# %%
ath.Height = ath.Height.astype('float')
ath.Weight = ath.Weight.astype('float')

# %%
ath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Gender  271116 non-null  object
#  3   Age     271116 non-null  int64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   Region  270746 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# List out all the values of the region columns where the values are null

# %%
ath[ath['Region'].isna()]
# Out:
#             ID                             Name Gender  Age     Height  \
# 578        332                 Zarinah Abdullah      F   21  175.33897
# 579        332                 Zarinah Abdullah      F   25  175.33897
# 2719      1515  Saiyidah Aisyah Mohamed Rafa'ee      F   28  173.00000
# 6267      3515              Paulo Amotun Lokoro      M   24  170.00000
# 7659      4264                   Ang Peng Siong      M   21  180.00000
# ...        ...                              ...    ...  ...        ...
# 268752  134454                    Zhang Guirong      F   26  182.00000
# 268753  134454                    Zhang Guirong      F   30  182.00000
# 268993  134587                    Zhang Xueling      F   21  163.00000
# 268994  134587                    Zhang Xueling      F   21  163.00000
# 269455  134826                       Zhou Yihan      F   22  168.00000
#
#            Weight                      Team Region        Games  Year  Season  \
# 578     70.702393                 Singapore    NaN  1992 Summer  1992  Summer
# 579     70.702393                 Singapore    NaN  1996 Summer  1996  Summer
# 2719    68.000000                 Singapore    NaN  2016 Summer  2016  Summer
# 6267    61.000000  Refugee Olympic Athletes    NaN  2016 Summer  2016  Summer
# 7659    75.000000                 Singapore    NaN  1984 Summer  1984  Summer
# ...           ...                       ...    ...          ...   ...     ...
# 268752  95.000000                 Singapore    NaN  2004 Summer  2004  Summer
# 268753  95.000000                 Singapore    NaN  2008 Summer  2008  Summer
# 268993  53.000000                 Singapore    NaN  2004 Summer  2004  Summer
# 268994  53.000000               Singapore-1    NaN  2004 Summer  2004  Summer
# 269455  54.000000                 Singapore    NaN  2016 Summer  2016  Summer
#
#                   City         Sport                                Event  \
# 578          Barcelona     Badminton            Badminton Women's Singles
# 579            Atlanta     Badminton            Badminton Women's Singles
# 2719    Rio de Janeiro        Rowing         Rowing Women's Single Sculls
# 6267    Rio de Janeiro     Athletics         Athletics Men's 1,500 metres
# 7659       Los Angeles      Swimming  Swimming Men's 100 metres Freestyle
# ...                ...           ...                                  ...
# 268752          Athina     Athletics           Athletics Women's Shot Put
# 268753         Beijing     Athletics           Athletics Women's Shot Put
# 268993          Athina  Table Tennis         Table Tennis Women's Singles
# 268994          Athina  Table Tennis         Table Tennis Women's Doubles
# 269455  Rio de Janeiro  Table Tennis            Table Tennis Women's Team
#
#        Medal
# 578      NaN
# 579      NaN
# 2719     NaN
# 6267     NaN
# 7659     NaN
# ...      ...
# 268752   NaN
# 268753   NaN
# 268993   NaN
# 268994   NaN
# 269455   NaN
#
# [370 rows x 15 columns]

# %%
for i in ath[ath['Region'].isna()]['Team']:
  print(i)
# Out:
# Singapore
# Singapore
# Singapore
# Refugee Olympic Athletes
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Refugee Olympic Athletes
# Refugee Olympic Athletes
# Refugee Olympic Athletes
# Singapore
# Singapore
# Singapore
# Singapore
# Refugee Olympic Athletes
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Refugee Olympic Athletes
# Singapore
# Singapore
# Singapore
# Singapore
# June Climene
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# June Climene
# Unknown
# Tuvalu
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Rika II
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Rika II
# Singapore
# Rika II
# June Climene
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore-2
# Rika II
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Refugee Olympic Athletes
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Unknown
# Tuvalu
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore-2
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Refugee Olympic Athletes
# Refugee Olympic Athletes
# Tuvalu
# Tuvalu
# Refugee Olympic Athletes
# Refugee Olympic Athletes
# Refugee Olympic Athletes
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Tuvalu
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore-1
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Tuvalu
# Tuvalu
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore-1
# Singapore

# %%
ath_cop = ath.copy()

# %%
ath_cop.Region.fillna("Team", inplace=True)

# %%
ath.Region.fillna("Team", inplace=True)

# %%
ath_cop[ath_cop['Region'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Gender, Age, Height, Weight, Team, Region, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
ath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Gender  271116 non-null  object
#  3   Age     271116 non-null  int64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   Region  271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# # Handling the null values in the column "Medals"

# %%
ath.head()
# Out:
#    ID                      Name Gender  Age     Height     Weight  \
# 0   1                 A Dijiang      M   24  180.00000  80.000000
# 1   2                  A Lamusi      M   23  170.00000  60.000000
# 2   3       Gunnar Nielsen Aaby      M   24  175.33897  70.702393
# 3   4      Edgar Lindenau Aabye      M   34  175.33897  70.702393
# 4   5  Christine Jacoba Aaftink      F   21  185.00000  82.000000
#
#              Team       Region        Games  Year  Season       City  \
# 0           China        China  1992 Summer  1992  Summer  Barcelona
# 1           China        China  2012 Summer  2012  Summer     London
# 2         Denmark      Denmark  1920 Summer  1920  Summer  Antwerpen
# 3  Denmark/Sweden      Denmark  1900 Summer  1900  Summer      Paris
# 4     Netherlands  Netherlands  1988 Winter  1988  Winter    Calgary
#
#            Sport                             Event Medal
# 0     Basketball       Basketball Men's Basketball   NaN
# 1           Judo      Judo Men's Extra-Lightweight   NaN
# 2       Football           Football Men's Football   NaN
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating  Speed Skating Women's 500 metres   NaN

# %%
ath.Medal.unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
ath.Medal.nunique()
# Out:
# 3

# %%
ath.Medal.value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
# Replace
# NaN -> 0
# Gold -> 1
# Silver -> 2
# Bronze -> 3

# %%
ath.Medal.replace([np.nan, 'Gold', 'Silver', 'Bronze'],[0, 1, 2, 3], inplace=True)

# %%
ath.Medal
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 271111    0
# 271112    0
# 271113    0
# 271114    0
# 271115    0
# Name: Medal, Length: 271116, dtype: int64

# %%
ath.Medal.value_counts()
# Out:
# 0    231333
# 1     13372
# 3     13295
# 2     13116
# Name: Medal, dtype: int64

# %%
ath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Gender  271116 non-null  object
#  3   Age     271116 non-null  int64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   Region  271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   271116 non-null  int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 31.0+ MB

# %%
ath.isnull().sum()
# Out:
# ID        0
# Name      0
# Gender    0
# Age       0
# Height    0
# Weight    0
# Team      0
# Region    0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %% [markdown]
# Delete some of the unwanted/irrelavant columns

# %%
ath.head(2)
# Out:
#    ID       Name Gender  Age  Height  Weight   Team Region        Games  Year  \
# 0   1  A Dijiang      M   24   180.0    80.0  China  China  1992 Summer  1992
# 1   2   A Lamusi      M   23   170.0    60.0  China  China  2012 Summer  2012
#
#    Season       City       Sport                         Event  Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball      0
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight      0

# %%
# Delete the columns - ID, Region, Games
ath.drop(['ID', 'Region', 'Games'], axis=1, inplace=True)

# %%
ath.head()
# Out:
#                        Name Gender  Age     Height     Weight            Team  \
# 0                 A Dijiang      M   24  180.00000  80.000000           China
# 1                  A Lamusi      M   23  170.00000  60.000000           China
# 2       Gunnar Nielsen Aaby      M   24  175.33897  70.702393         Denmark
# 3      Edgar Lindenau Aabye      M   34  175.33897  70.702393  Denmark/Sweden
# 4  Christine Jacoba Aaftink      F   21  185.00000  82.000000     Netherlands
#
#    Year  Season       City          Sport                             Event  \
# 0  1992  Summer  Barcelona     Basketball       Basketball Men's Basketball
# 1  2012  Summer     London           Judo      Judo Men's Extra-Lightweight
# 2  1920  Summer  Antwerpen       Football           Football Men's Football
# 3  1900  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  1988  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres
#
#    Medal
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0

# %% [markdown]
# Remove the unwanted phrases from the "Event" Column

# %%
ath[['Sport', 'Event']]
# Out:
#                 Sport                                     Event
# 0          Basketball               Basketball Men's Basketball
# 1                Judo              Judo Men's Extra-Lightweight
# 2            Football                   Football Men's Football
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War
# 4       Speed Skating          Speed Skating Women's 500 metres
# ...               ...                                       ...
# 271111           Luge                Luge Mixed (Men)'s Doubles
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team
# 271114      Bobsleigh                      Bobsleigh Men's Four
# 271115      Bobsleigh                      Bobsleigh Men's Four
#
# [271116 rows x 2 columns]

# %%
for i,j in zip(ath.Sport, range(len(ath.Event))):
  ath.Event[j] = re.sub(f'^{i}\s', '', ath.Event[j])
# Out:
# <ipython-input-61-4745c79469fe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ath.Event[j] = re.sub(f'^{i}\s', '', ath.Event[j])

# %%
ath.head()
# Out:
#                        Name Gender  Age     Height     Weight            Team  \
# 0                 A Dijiang      M   24  180.00000  80.000000           China
# 1                  A Lamusi      M   23  170.00000  60.000000           China
# 2       Gunnar Nielsen Aaby      M   24  175.33897  70.702393         Denmark
# 3      Edgar Lindenau Aabye      M   34  175.33897  70.702393  Denmark/Sweden
# 4  Christine Jacoba Aaftink      F   21  185.00000  82.000000     Netherlands
#
#    Year  Season       City          Sport                    Event  Medal
# 0  1992  Summer  Barcelona     Basketball         Men's Basketball      0
# 1  2012  Summer     London           Judo  Men's Extra-Lightweight      0
# 2  1920  Summer  Antwerpen       Football           Men's Football      0
# 3  1900  Summer      Paris     Tug-Of-War         Men's Tug-Of-War      1
# 4  1988  Winter    Calgary  Speed Skating       Women's 500 metres      0

# %%
ath.shape
# Out:
# (271116, 12)

# %%
ath.duplicated().sum()
# Out:
# 1385

# %%
ath[ath.duplicated()]
# Out:
#                                        Name Gender  Age     Height     Weight  \
# 1252                     Dsir Antoine Acket      M   27  175.33897  70.702393
# 4282                 William Truman Aldrich      M   48  175.33897  70.702393
# 4283                 William Truman Aldrich      M   48  175.33897  70.702393
# 4862                 Hermann Reinhard Alker      M   43  175.33897  70.702393
# 4864                 Hermann Reinhard Alker      M   43  175.33897  70.702393
# ...                                     ...    ...  ...        ...        ...
# 269994  Anna Katrina Zinkeisen (-Heseltine)      F   46  175.33897  70.702393
# 269995  Anna Katrina Zinkeisen (-Heseltine)      F   46  175.33897  70.702393
# 269997  Anna Katrina Zinkeisen (-Heseltine)      F   46  175.33897  70.702393
# 269999   Doris Clare Zinkeisen (-Johnstone)      F   49  175.33897  70.702393
# 270200                     Henri Achille Zo      M   58  175.33897  70.702393
#
#                  Team  Year  Season         City             Sport  \
# 1252          Belgium  1932  Summer  Los Angeles  Art Competitions
# 4282    United States  1928  Summer    Amsterdam  Art Competitions
# 4283    United States  1928  Summer    Amsterdam  Art Competitions
# 4862          Germany  1928  Summer    Amsterdam  Art Competitions
# 4864          Germany  1928  Summer    Amsterdam  Art Competitions
# ...               ...   ...     ...          ...               ...
# 269994  Great Britain  1948  Summer       London  Art Competitions
# 269995  Great Britain  1948  Summer       London  Art Competitions
# 269997  Great Britain  1948  Summer       London  Art Competitions
# 269999  Great Britain  1948  Summer       London  Art Competitions
# 270200         France  1932  Summer  Los Angeles  Art Competitions
#
#                                                 Event  Medal
# 1252                    Mixed Painting, Unknown Event      0
# 4282        Mixed Painting, Drawings And Water Colors      0
# 4283        Mixed Painting, Drawings And Water Colors      0
# 4862    Mixed Architecture, Designs For Town Planning      0
# 4864        Mixed Architecture, Architectural Designs      0
# ...                                               ...    ...
# 269994                      Mixed Painting, Paintings      0
# 269995                      Mixed Painting, Paintings      0
# 269997                  Mixed Painting, Unknown Event      0
# 269999                  Mixed Painting, Unknown Event      0
# 270200                  Mixed Painting, Unknown Event      0
#
# [1385 rows x 12 columns]

# %%
ath.loc[ath['Name']=='Dsir Antoine Acket']
# Out:
#                     Name Gender  Age     Height     Weight     Team  Year  \
# 1251  Dsir Antoine Acket      M   27  175.33897  70.702393  Belgium  1932
# 1252  Dsir Antoine Acket      M   27  175.33897  70.702393  Belgium  1932
#
#       Season         City             Sport                          Event  \
# 1251  Summer  Los Angeles  Art Competitions  Mixed Painting, Unknown Event
# 1252  Summer  Los Angeles  Art Competitions  Mixed Painting, Unknown Event
#
#       Medal
# 1251      0
# 1252      0

# %%
ath.drop_duplicates(inplace=True)

# %%
ath.reset_index(inplace=True)

# %%
ath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269731 entries, 0 to 269730
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   index   269731 non-null  int64
#  1   Name    269731 non-null  object
#  2   Gender  269731 non-null  object
#  3   Age     269731 non-null  int64
#  4   Height  269731 non-null  float64
#  5   Weight  269731 non-null  float64
#  6   Team    269731 non-null  object
#  7   Year    269731 non-null  int64
#  8   Season  269731 non-null  object
#  9   City    269731 non-null  object
#  10  Sport   269731 non-null  object
#  11  Event   269731 non-null  object
#  12  Medal   269731 non-null  int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 26.8+ MB

# %%
ath.drop('index', axis=1, inplace=True)

# %%
ath.head()
# Out:
#                        Name Gender  Age     Height     Weight            Team  \
# 0                 A Dijiang      M   24  180.00000  80.000000           China
# 1                  A Lamusi      M   23  170.00000  60.000000           China
# 2       Gunnar Nielsen Aaby      M   24  175.33897  70.702393         Denmark
# 3      Edgar Lindenau Aabye      M   34  175.33897  70.702393  Denmark/Sweden
# 4  Christine Jacoba Aaftink      F   21  185.00000  82.000000     Netherlands
#
#    Year  Season       City          Sport                    Event  Medal
# 0  1992  Summer  Barcelona     Basketball         Men's Basketball      0
# 1  2012  Summer     London           Judo  Men's Extra-Lightweight      0
# 2  1920  Summer  Antwerpen       Football           Men's Football      0
# 3  1900  Summer      Paris     Tug-Of-War         Men's Tug-Of-War      1
# 4  1988  Winter    Calgary  Speed Skating       Women's 500 metres      0

# %% [markdown]
# # Data Exportation

# %%
# Export to JSON
ath.to_json('olympics_dataset.json')

# Export to Excel
ath.to_excel('olympics_dataset.xlsx')

# Export to JSON
ath.to_csv('olympics_dataset.csv')

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # Data Analysis

# %% [markdown]
# 1. Show the relationship b/w Height & Weight

# %%
plt.scatter(ath.Height, ath.Weight)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height Vs Weight')
# Out:
# Text(0.5, 1.0, 'Height Vs Weight')

# %% [markdown]
# 2. Find out how many Male & Female has participated in the Olympics w.r.t. the given dataset (Data Visulisation)

# %% [markdown]
# 3. How many Male and Female have participated in the Summer & Winter Olympics

# %% [markdown]
# 4. Name the Top 5 countries who're having the most medals

# %% [markdown]
# 5. How many medals did the Female athlete have won during the Summer Olympics?

# %% [markdown]
# 6. Name all the cities where the 2012 Olympics was held.

# %%
ath['City'][ath.Year==2012].unique()
# Out:
# array(['London'], dtype=object)

# %% [markdown]
# 7. Name all the athletes who has participated in the game 'Judo'

# %%
ath[['Name','Sport']][ath.Sport=='Judo']
# Out:
#                              Name Sport
# 1                        A Lamusi  Judo
# 160                M'Bairo Abakar  Judo
# 180                  Salim Abanoz  Judo
# 412          Mohamed Ali Abdelaal  Judo
# 435             Ahmed Abdelrahman  Judo
# ...                           ...   ...
# 269468             Oleg Zurabiani  Judo
# 269533                Goran uvela  Judo
# 269596            Zurab Zviadauri  Judo
# 269647  Claudia Antoinette Zwiers  Judo
# 269648  Claudia Antoinette Zwiers  Judo
#
# [3801 rows x 2 columns]
